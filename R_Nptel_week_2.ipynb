# %% [markdown]
# **NPTEL-Week-02: Basics of Calculations, Foundations of R software**
#
#
# **Name**: Yashraj Patil
#
# **Roll no**: 23102A0071
#
# **Department and Division**: CMPN-A
#
# **Lab mentor**: Prof. Prakash Parmar

# %% [markdown]
# Addition with data vectors

# %%
c(2,3,5,7) + c(-2,-3, -5, 8)
# Out:
# [1]  0  0  0 15

# %%
c (2,3,5,7) + c(-2,-3,-5, 8)
# Out:
# [1]  0  0  0 15

# %%
c(2,3,5,7) + c(8,9) # !!! ATTENTION!
# Out:
# [1] 10 12 13 16

# %%
 c(2,3,5,7) + c(8,9,10) # error message
# Out:
# Warning message in c(2, 3, 5, 7) + c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 10 12 15 15

# %% [markdown]
# Subtraction with data vectors

# %%
c(2,3,5,7) - c(-2,-3, -5, 8)
# Out:
# [1]  4  6 10 -1

# %%
c(12,13,15,17) - c(8,9) # !!! ATTENTION!
# Out:
# [1] 4 4 7 8

# %%
c(12,13,15,17) - c(8,9,10) # error message
# Out:
# Warning message in c(12, 13, 15, 17) - c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 4 4 5 9

# %% [markdown]
# Multiplication with data vector

# %%
c(2,3,5,7) * c(-2,-3,-5,8)
# Out:
# [1]  -4  -9 -25  56

# %%
c(2,3,5,7) * c(8,9) # !!! ATTENTION
# Out:
# [1] 16 27 40 63

# %%
c(2,3,5,7) * c(8,9,10) # error message
# Out:
# Warning message in c(2, 3, 5, 7) * c(8, 9, 10):
# “longer object length is not a multiple of shorter object length”
# [1] 16 27 50 56

# %% [markdown]
# Division with Data Vectors

# %%
c(24,20,8,16) / c(3,4,2,8)
# Out:
# [1] 8 5 4 2

# %%
c(24,20,8,16) / c(4,2) # !!! ATTENTION
# Out:
# [1]  6 10  2  8

# %%
c(24,20,8,16) / c(4,2,8) # error message
# Out:
# Warning message in c(24, 20, 8, 16)/c(4, 2, 8):
# “longer object length is not a multiple of shorter object length”
# [1]  6 10  1  4

# %% [markdown]
# **Some more Basic Operations in R**

# %% [markdown]
# Assignment operator

# %%
x <- 20

# %%
x
# Out:
# [1] 20

# %%
x = 20

# %%
x
# Out:
# [1] 20

# %%
y = x * 2

# %%
y
# Out:
# [1] 40

# %%
z = x + y

# %%
z
# Out:
# [1] 60

# %% [markdown]
# The characters assigned within double or single quotes

# %%
x = "apple"

# %%
x
# Out:
# [1] "apple"

# %%
x <- "apple1"

# %%
x
# Out:
# [1] "apple1"

# %%
x = 'apple'

# %% [markdown]
# **Knowing numbers and characters**

# %%
x = 20
is.numeric(x)
# Out:
# [1] TRUE

# %%
 is.character(x)
# Out:
# [1] FALSE

# %%
 y = "apple"
is.character(y)
is.numeric(y)
# Out:
# [1] TRUE
# [1] FALSE

# %% [markdown]
# **Converting numbers and characters**

# %%
x = 20

# %%
is.numeric(x)
# Out:
# [1] TRUE

# %%
y = as.character(x)
is.numeric(y)
is.character(y)
# Out:
# [1] FALSE
# [1] TRUE

# %%
is.character(y)
# Out:
# [1] TRUE

# %%
y
# Out:
# [1] "20"

# %% [markdown]
# **Converting numbers and characters**

# %%
y = "apple"

# %%
is.numeric(y)
# Out:
# [1] FALSE

# %%
 is.character(y)
# Out:
# [1] TRUE

# %%
z = as.numeric(y)
# Out:
# Warning message:
# “NAs introduced by coercion”

# %%
is.numeric(z)
# Out:
# [1] TRUE

# %%
is.character(z)
# Out:
# [1] FALSE

# %% [markdown]
# **Comment operator**

# %% [markdown]
# **Case sensitivity in R**

# %%
X <- 20

# %%
X
# Out:
# [1] 20

# %%
x <- 20

# %%
x
# Out:
# [1] 20

# %%
x <- 30

# %%
X
# Out:
# [1] 20

# %%
x
# Out:
# [1] 30

# %% [markdown]
# **Combining values in a data vector **

# %%
y = 1,2,3,4,5
# Out:
# Error in parse(text = input): <text>:1:6: unexpected ','
# 1: y = 1,
#          ^
# Traceback:

# %%
y =(1,2,3,4,5)
# Out:
# Error in parse(text = input): <text>:1:6: unexpected ','
# 1: y =(1,
#          ^
# Traceback:

# %%
y = c(1,2,3,4,5)

# %%
y
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# Mode

# %%
x = 6

# %%
x
# Out:
# [1] 6

# %%
mode(x)
# Out:
# [1] "numeric"

# %%
y = "apple"

# %%
y
# Out:
# [1] "apple"

# %%
mode(y)
# Out:
# [1] "character"

# %%
x = 6 #numeric
storage.mode(x)
# Out:
# [1] "double"

# %%
x = TRUE #logical
storage.mode(x)
# Out:
# [1] "logical"

# %%
x = "apple" #character
storage.mode(x)
# Out:
# [1] "character"

# %% [markdown]
# **Infinity**

# %%
3/0
# Out:
# [1] Inf

# %%
5+Inf
# Out:
# [1] Inf

# %%
x = 5+Inf

# %%
is.finite(x)
# Out:
# [1] FALSE

# %%
is.infinite(x)
# Out:
# [1] TRUE

# %% [markdown]
# **R as a calculator**

# %%
2+3
# Out:
# [1] 5

# %%
2*3
# Out:
# [1] 6

# %%
2-3
# Out:
# [1] -1

# %%
3/2
# Out:
# [1] 1.5

# %%
2*3-4+5/6
# Out:
# [1] 2.833333

# %%
(2+3)*5 + 5 - 10 # Command for BODMAS
# Out:
# [1] 20

# %%
(((2+3)*5 + 5) - 10)/2 # Command for BODMAS
# Out:
# [1] 10

# %% [markdown]
# Blank space has no role in calculations

# %%
2+5
# Out:
# [1] 7

# %%
2  +  5
# Out:
# [1] 7

# %%
2               +5
# Out:
# [1] 7

# %% [markdown]
# **Addition with scalar**

# %%
c(2,3,5,7) + 10
# Out:
# [1] 12 13 15 17

# %% [markdown]
# **Subtraction with scalar**

# %%
c(12,13,15,17) - 10
# Out:
# [1] 2 3 5 7

# %% [markdown]
# **Multiplication  with scalar**

# %%
c(2,3,5,7) * 10
# Out:
# [1] 20 30 50 70

# %% [markdown]
# **Division with scalar**

# %%
c(12,13,15,17) / 10
# Out:
# [1] 1.2 1.3 1.5 1.7
