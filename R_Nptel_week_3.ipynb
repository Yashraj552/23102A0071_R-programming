# %% [markdown]
# **NPTEL-Week-03: Calculations with Data Vectors :
# Addition, Subtraction, Multiplication & Division**
#
#
# **Name**: Yashraj Patil
#
# **Roll no**: 23102A0071
#
# **Department and Division**: CMPN-A
#
# **Lab mentor**: Prof. Prakash Parmar

# %% [markdown]
# ### Addition with data vectors

# %%
 c(2,3,5,7) + c (-2, -3, -5 ,8 )
# Out:
# [1]  0  0  0 15

# %% [markdown]
# ###Power operator with scalar and vector

# %%
2^3
# Out:
# [1] 8

# %%
2**3
# Out:
# [1] 8

# %%
2^0.5
# Out:
# [1] 1.414214

# %%
2**0.5
# Out:
# [1] 1.414214

# %%
2^-0.5
# Out:
# [1] 0.7071068

# %%
c(2,3,5,7)^2
# Out:
# [1]  4  9 25 49

# %%
c(2,3,5,7)^c(2,3)
# Out:
# [1]   4  27  25 343

# %%
c(1,2,3,4,5,6)^c(2,3,4)
# Out:
# [1]    1    8   81   16  125 1296

# %%
c(2,3,5,7)^c(2,3,4)
# Out:
# Warning message in c(2, 3, 5, 7)^c(2, 3, 4):
# “longer object length is not a multiple of shorter object length”
# [1]   4  27 625  49

# %% [markdown]
# ## Integer division with scalar and data vector

# %%
2 %% 2
# Out:
# [1] 0

# %%
5 %% 2
# Out:
# [1] 1

# %%
7 %% 3
# Out:
# [1] 1

# %%
c(2,3,5,7) %/% 2
# Out:
# [1] 1 1 2 3

# %%
c (2,3,5,7) %/% c(2,3)
# Out:
# [1] 1 1 2 2

# %%
c(2,3,5) %/% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%/%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 1 1 2

# %% [markdown]
# ### Modulo Division (x mod y) with scalars

# %%
2 %% 2
# Out:
# [1] 0

# %%
3 %% 2
# Out:
# [1] 1

# %%
7 %% 3
# Out:
# [1] 1

# %%
7 %% 4
# Out:
# [1] 3

# %%
c(2,3,5,7) %% 2
# Out:
# [1] 0 1 1 1

# %%
c (2,3,5,7) %% c(2,3)
# Out:
# [1] 0 0 1 1

# %%
c(2,3,5) %% c(2,3)
# Out:
# Warning message in c(2, 3, 5)%%c(2, 3):
# “longer object length is not a multiple of shorter object length”
# [1] 0 0 1

# %% [markdown]
# ###Maximum Operator: max

# %%
max (1.2, 3.4, -7.8)
# Out:
# [1] 3.4

# %%
max (c(1.2,3.4, -7.8))
# Out:
# [1] 3.4

# %% [markdown]
# ### Minimum Operator: *min*

# %%
min (1.2, 3.4, -7.8)
# Out:
# [1] -7.8

# %%
min (c(1.2,3.4, -7.8))
# Out:
# [1] -7.8

# %% [markdown]
# ## Arithmetic mean Operator: mean

# %%
mean(2,3,4)
# Out:
# [1] 2

# %%
 mean(c(2, 3, 4))
# Out:
# [1] 3

# %% [markdown]
# ### Operator: abs for finding the absolute values

# %%
abs(-4)
# Out:
# [1] 4

# %%
abs(c(-1,-2,-3,4,5))
# Out:
# [1] 1 2 3 4 5

# %% [markdown]
# ### Operator: sqrt for finding the square root of values

# %%
sqrt(4)
# Out:
# [1] 2

# %%
sqrt(c(4,9,16,25))
# Out:
# [1] 2 3 4 5

# %% [markdown]
# ### Operator: sum for finding the sum of values

# %%
sum(c(2,3,5,7))
# Out:
# [1] 17

# %% [markdown]
# ###Operator: prod for finding the product of values

# %%
prod(c(2,3,5,7))
# Out:
# [1] 210

# %% [markdown]
# ### Operator: round for finding the round off

# %%
round(1.23)
# Out:
# [1] 1

# %%
round(1.83)
# Out:
# [1] 2

# %% [markdown]
# ##Operator: log for finding the natural log (ln) of values

# %%
log(10)
# Out:
# [1] 2.302585

# %%
log(exp(1))
# Out:
# [1] 1

# %%
log(c(10,100,1000))
# Out:
# [1] 2.302585 4.605170 6.907755

# %% [markdown]
# ###Operator: log10 for finding the log (with base 10) of values

# %%
log10(10)
# Out:
# [1] 1

# %%
log10(100)
# Out:
# [1] 2

# %%
log10(c(10,100,1000))
# Out:
# [1] 1 2 3

# %% [markdown]
# ### Assignments
# An assignment can also be used to save values in variables:

# %%
x1 = c(1,2,3,4)

# %%
x1
# Out:
# [1] 1 2 3 4

# %%
x2 = x1^2
x2
# Out:
# [1]  1  4  9 16

# %% [markdown]
# ### Assignments
# Calculations with scalar, data vector and built in functions also work.

# %%
c(1,2,3,4) + sum(c(1,2,3,4)) * prod(1,2)
# Out:
# [1] 21 22 23 24

# %%
abs(c(1,2,3,4)) - sum (c(1,2,3,4))* prod(c(1,2))
# Out:
# [1] -19 -18 -17 -16

# %% [markdown]
# ###Matrix
# Matrices are important objects in any calculation.
#
# A matrix is a rectangular array with p rows and n columns.

# %%
x = matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8))

# %%
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %% [markdown]
# ###Matrix parameters

# %%
x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
x[3,2]
# Out:
# [1] 7

# %% [markdown]
# ### Entering data column wise in a matrix

# %%
x = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8))

# %%
x = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8), byrow = FALSE)

# %% [markdown]
# ## Entering data row wise in a matrix

# %%
y = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8), byrow = TRUE)

# %%
 x = matrix( nrow=4, ncol=2,
data=c(1,2,3,4,5,6,7,8) )

# %% [markdown]
# ##Properties of a Matrix

# %%
dim(x)
# Out:
# [1] 4 2

# %%
nrow(x)
# Out:
# [1] 4

# %%
ncol(x)
# Out:
# [1] 2

# %%
mode(x)
# Out:
# [1] "numeric"

# %%
attributes(x)
# Out:
# $dim
# [1] 4 2

# %%
help("matrix")
